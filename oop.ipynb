# %% [markdown]
# ## Challenge 🤺15 min
#
# Crear una clase animales que tenga atributo de clase y de instancia.
#
# - Atributos de clase: `especie`.
# - Atributos de instancia: `nombre` & `color`
# .
# Luego, crear nuevos objetos a partir de las nuevas class. Imprimir el nombre y el color de los animales en una frase.
# Ejemplo: "Me llamo `{nombre}` y soy un ave de color `{color}`".

# %%
class Animales:
    Especie = 'aves'
    def __init__(self, nombre, color):
        self.nombre = nombre
        self.color = color
    def __str__(self):
        return f"Me llamo {self.nombre} y soy un ave de color {self.color}"
aguila = Animales ('aguila','blanca')
print(aguila)
# Out:
# Me llamo aguila y soy un ave de color blanca

# %%
class Animales:
    Especie = 'aves'
    def __init__(self, nombre, color):
        self.nombre = nombre
        self.color = color

pajaro = Animales("pajaro","marron")
print (f"Me llamo {pajaro.nombre} y soy un ave de color {pajaro.color}")
# Out:
# Me llamo pajaro y soy un ave de color marron

# %%
## Challenge 🤺
##Crear dos métodos para nuestro animal y ejecutar, debe ser algo específico de ese animal.

#Ejemplo: "Cuando hablo, digo X".
#Ejemplo: "Cuando me muevo, hago X".
class Animal:
    def __init__(self, hablar, mover):
        self.emito = hablar 
        self.hago = mover
    def hablar (self):
        print(f'cuando hablo, digo {self.emito}')
    def mover (self):
        print(f'cuando me muevo, hago {self.hago}')
perro = Animal('waf', 'popo')
perro.hablar()
perro.mover ()
# Out:
# cuando hablo, digo waf
# cuando me muevo, hago popo

# %%
## Challenge 🤺15 min
#Definir una clase madre que herede a sus clases hijas dos atributos de instancia. 
# Mostrar ambos atributos en pantalla desde los objetos de las clases hijas.

#Observación: Editar las clases hijas para que no se inicialicen.##

class Futbol:
    def __init__(self, equipo, seleccion):
        self.club = equipo 
        self.pais = seleccion
    
class Jugadores (Futbol):
    def __init__(self, posicion, edad, peso, nombre):
        self.juega = posicion
        self.año = edad
        self.kilos = peso
        self.mellamo = nombre 
        print (f'Me llamo {self.mellamo}, juego en la psicion {self.juega}, tengo {self.año}, peso {peso}')
              
class Tecnicos (Futbol):
    def __init__(self, edad, nombre, cargo):
        self.año = edad
        self.sellama = nombre
        self.jerarquia = cargo
        print (f'me llamo {self.sellama}, tengo ))

# %%
## Challenge 🤺
#Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un hereo y un villano.
#Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.
#Ejemplo: Yo me llamo pepito y tengo super fuerza
#Ejemplo: Yo me llamo juanito y puedo volar'
