# %%
dicicionario = {}
nombre_usuario = input ('Nombre usuario')

# %%
datos = {}
tarjeta_personal = input ('ingrese opcion')
if tarjeta_personal == "1" : 
    clave_usuario = input ('ingrese clave')
    valor_usuario = input ('ingrese valor')
    datos[clave_usuario] = valor_usuario
    print (datos)

elif tarjeta_personal == '2':
    clave_usuario = input ('ingrese clave')
    valor_usuario = input("Modifica tu valor")
    datos[clave_usuario] = valor_usuario
    datos 
    print (datos)
else
# Out:
#   Cell In[34], line 15
#     else
#          ^
# SyntaxError: expected ':'

# %% [markdown]
# Crear una agenda de contactos. El usuario puede elegir:
#
# Mostrar los contactos
# Crear contacto
# Modificar datos del contacto

# %%
agenda_de_contactos = {'Carlos':{'nombre': "Carlos", 'numero': '0983071255'},"Oliver":{'nombre' : 'Oliver', 'numero' : '0971255757'}}

print (agenda_de_contactos)
clave = 'Carlos'
valor = {'nombre': "Carlos", 'numero': '0983071255'}
agenda_de_contactos [clave] = valor 
print (agenda_de_contactos)
if
# Out:
# {'Carlos': {'nombre': 'Carlos', 'numero': '0983071255'}, 'Oliver': {'nombre': 'Oliver', 'numero': '0971255757'}}
# {'Carlos': {'nombre': 'Carlos', 'numero': '0983071255'}, 'Oliver': {'nombre': 'Oliver', 'numero': '0971255757'}}
