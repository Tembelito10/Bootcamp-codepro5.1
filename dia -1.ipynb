# %%
print('hola mundo')
# Out:
# hola mundo

# %%
fruta = 'naranja' 
print('naranja')
# Out:
# naranja

# %%
nombre ='carlos'
edad =23 #numero
ciudad ='Limpio'
print('nombre')
print('edad')
print('ciudad')
# Out:
# nombre
# edad
# ciudad

# %%
# sta
frutas_vendidas = 5
cantidad_de_fruta =

# %%
nombre= 'carlos'
apellido= 'balbuena'
print(nombre + ' ' + apellido)
print(f'mi nombre es {nombre} {apellido}')
# Out:
# carlos balbuena
# mi nombre es carlos balbuena

# %%
caramelo_usuario = int(input('ingresa cantidad de caramelos'))
niños_usuario = int(input('cantidad de niños'))
caramelo_niño = caramelo_usuario/ niños_usuario
print('total' , caramelo_niño)
# Out:
# total 3.0

# %%
def presentacion():
    nombre = input('ingrese nombre')
    apellido = input('ingrese apellido')
    edad = input('ingrese edad')
    carrera = input('ingrese carrera')
    print(f'Hola mi nombre es {nombre} {apellido}, tengo {edad} años, y soy estudiante de la carrera {carrera}')


presentacion()
presentacion()
presentacion()
# Out:
# Hola mi nombre es Carlos Balbuena, tengo 23 años, y soy estudiante de la carrera Ing Informatica
# Hola mi nombre es Sofia Quintana, tengo 25 años, y soy estudiante de la carrera Artes
# Hola mi nombre es Paula Cubilla, tengo 26 años, y soy estudiante de la carrera Relaciones Internacionales

# %%
pedido_comida = input('tipo de comida')
pedido_bebida = input('tipo de bebida')
pedido_postre= input('tipo de postre')

def preparar_pedido(comida, bebida, postre):
     print(f'preparando tu pedido: {comida} con {bebida} y {postre}')     
     print('pedido entregado')   

preparar_pedido(pedido_comida, pedido_bebida, pedido_postre)
# Out:
# preparando tu pedido: Lomito Arabe con Cerveza y Helado
# pedido entregado

# %%
producto_ropa = input('precio de la ropa')
impuesto = 0.1
def calcular_total(productuo_ropa, impuesto)
    print(f'Total a pagar: {producto_ropa} + {impuesto}')

calcular_total()
# Out:
#   Cell In[97], line 3
#     def calcular_total(productuo_ropa, impuesto)
#                                                 ^
# SyntaxError: expected ':'
