# %%
def imprimir():
    print ('palabra')
imprimir()
# Out:
# palabra

# %%
def comparacion(letra1, letra2):
    letra1= 'c'
    letra2= 'p'
    print(letra1, letra2)
    comparacion('a',)

# %%
def palabras_y_numeros (palabra, numero ):
    if len



    palabra = input('Ingrese la palabra')

# %%
usuario = input('Ingrese la palabra')
palabras_ingresadas = list (usuario)
print (palabras_ingresadas)
usuario = input('Ingrese la palabra')
palabras_ingresadas = list (usuario)
print (palabras_ingresadas)
usuario = input('Ingrese la palabra')
palabras_ingresadas = list (usuario)
print (palabras_ingresadas)
# Out:
# ['h', 'o', 'l', 'a']
# ['q', 'u', 'e']
# ['t', 'a', 'l']

# %%
palabra_secreta = 'Datos'
intentos = 5
cantidad_de_letra_a_encontrar = 5
usuario = input ('Ingrese la palabra secreta')
palabra_ingresada = list(usuario)
print(palabra_ingresada)

def obtener_fila_verificada(palabra_a_encontrar, palabra_ingresada):
    cantidad_letras_de_palabra_a_encontrar = 5

    #creamos una lista vacia para almacenar el resultado
    letras_verificadas = []

    for posicion in range(cantidad_letras_de_palabra_a_encontrar): #5

        # es ogual el indice 0 de palabra_a_encontrar a indice 0 de palabra_ingresada?
        las_letras_son_iguales = palabra_a_encontrar[posicion] == palabra_ingresada[posicion]


        # la letra del indice 0 de palabra_ingresada en la palabra_a_encontrar
        la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in palabra_a_encontrar

        if las_letras_son_iguales:
            # si se cumple guardamos en la lista de letras verificadas
            letras_verificadas.append('['+palabra_ingresada[posicion]+']')

        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append('('+palabra_ingresada[posicion]+')')

        else:
            letras_verificadas.append(palabra_ingresada[posicion])

        
    return letras_verificadas

resultado = obtener_fila_verificada('perro, gato')
print(resultado)
while intentos > 0:
    print(f'te quedan {intentos} intentos')
    palabra = input(' ingrese una palabra')

    # logica para verificar la palabra


    intentos = intentos - 1
    print(palabra)



print('lo siento, ya no quedan intentos')

# %%
lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
    def lista (lista_de_listas)
lista ()

# %%
palabra_secreta = 'Datos'
intentos = 5
cantidad_de_letra_a_encontrar = 5
usuario = input ('Ingrese la palabra secreta')
def posicion (palabra_secreta, usario):
    for posi

# %%
# configuracion inicial
palabra_secreta = 'gatos'
intentos = 3

# bucle principal
while intentos > 0:
    print(f'te quedan {intentos} intentos')
    palabra = input(' ingrese una palabra')

    # logica para verificar la palabra


    intentos = intentos - 1
    print(palabra)
# Out:
#   Cell In[32], line 17
#     cantidad_letras_de_palabra_a_encontrar = 5
#     ^
# IndentationError: expected an indented block after function definition on line 16

# %%
def obtener_fila_verificada(palabra_a_encontrar, palabra_ingresada):
    cantidad_letras_de_palabra_a_encontrar = 5

    #creamos una lista vacia para almacenar el resultado
    letras_verificadas = []

    for posicion in range(cantidad_letras_de_palabra_a_encontrar): #5

        # es ogual el indice 0 de palabra_a_encontrar a indice 0 de palabra_ingresada?
        las_letras_son_iguales = palabra_a_encontrar[posicion] == palabra_ingresada[posicion]


        # la letra del indice 0 de palabra_ingresada en la palabra_a_encontrar
        la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in palabra_a_encontrar

        if las_letras_son_iguales:
            # si se cumple guardamos en la lista de letras verificadas
            letras_verificadas.append('['+palabra_ingresada[posicion]+']')

        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append('('+palabra_ingresada[posicion]+')')

        else:
            letras_verificadas.append(palabra_ingresada[posicion])

        
    return letras_verificadas

resultado = obtener_fila_verificada('perro', 'juego')
print(resultado)


print('ya no quedan intentos')

# %%
palabra_a_adivinar= 'dato'
usuario = ('ingrese la palabra')
input (usuario)
# Out:
# 'gsa'
